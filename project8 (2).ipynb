# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np

data = {
    'Date': pd.to_datetime(pd.date_range(start='2023-01-01', periods=100, freq='D')),
    'Store': np.random.choice([f'Store_{i}' for i in range(1, 11)], 100),
    'Item': np.random.choice([f'Item_{i}' for i in range(1, 21)], 100),
    'Sales': np.random.randint(100, 1000, 100)
}
dummy_df = pd.DataFrame(data)
dummy_df.to_csv('sales.csv', index=False)

print("Generated a dummy 'sales.csv' file.")
# Out:
# Generated a dummy 'sales.csv' file.

# %%
df = pd.read_csv('sales.csv')

# %%
print("First 5 Rows:")
print(df.head())
# Out:
# First 5 Rows:
#          Date     Store     Item  Sales
# 0  2023-01-01   Store_7  Item_17    291
# 1  2023-01-02   Store_9   Item_6    127
# 2  2023-01-03  Store_10  Item_12    700
# 3  2023-01-04   Store_3  Item_10    909
# 4  2023-01-05   Store_6  Item_17    288

# %%
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    100 non-null    object
#  1   Store   100 non-null    object
#  2   Item    100 non-null    object
#  3   Sales   100 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB
# None

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Date     0
# Store    0
# Item     0
# Sales    0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
print("\nStatistics:")
print(df['Sales'].describe())
# Out:
# Statistics:
# count    100.000000
# mean     522.370000
# std      268.978414
# min      126.000000
# 25%      268.000000
# 50%      499.500000
# 75%      759.250000
# max      999.000000
# Name: Sales, dtype: float64

# %%
total_sales = df['Sales'].sum()
avg_sales = df['Sales'].mean()
max_sales = df['Sales'].max()
min_sales = df['Sales'].min()

# %%
print("\nTotal Sales:", total_sales)
print("Average Sales:", avg_sales)
print("Max Sales:", max_sales)
print("Min Sales:", min_sales)
# Out:
# Total Sales: 52237
# Average Sales: 522.37
# Max Sales: 999
# Min Sales: 126

# %%
plt.figure()
df.groupby('Date')['Sales'].sum().plot()
plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
df['Month'] = df['Date'].dt.month
monthly_sales = df.groupby('Month')['Sales'].sum()

# %%
plt.figure()
monthly_sales.plot(kind='bar')
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
store_sales = df.groupby('Store')['Sales'].sum()

# %%
plt.figure()
store_sales.plot(kind='bar')
plt.title("Sales by Store")
plt.xlabel("Store")
plt.ylabel("Sales")
plt.show()

# %%
item_sales = df.groupby('Item')['Sales'].sum().sort_values(ascending=False).head(10)

# %%
plt.figure()
item_sales.plot(kind='bar')
plt.title("Top 10 Products")
plt.xlabel("Item")
plt.ylabel("Sales")
plt.show()

# %%
plt.figure()
plt.hist(df['Sales'])
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
sns.boxplot(x=df['Sales'])
plt.title("Sales Boxplot")
plt.show()

# %%
plt.figure()
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
daily_sales = df.groupby('Date')['Sales'].sum()

# %%
plt.figure()
daily_sales.plot()
plt.title("Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
print("\n EDA Completed Successfully!")
# Out:
#  EDA Completed Successfully!
